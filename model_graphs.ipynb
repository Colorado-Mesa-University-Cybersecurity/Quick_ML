# %%
! echo "y" | conda install -c anaconda graphviz
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.14.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done

# %%
! echo "y" | conda install -c anaconda mxnet
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.14.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/jameshalladay/opt/anaconda3/envs/ai
#
#   added / updated specs:
#     - mxnet
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _mutex_mxnet-0.0.50        |         openblas          10 KB
#     brotlipy-0.7.0             |py37h9ed2024_1003         358 KB  anaconda
#     bzip2-1.0.8                |       h1de35cc_0         104 KB  anaconda
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          33 KB  anaconda
#     cryptography-37.0.1        |   py37hf6deb26_0         1.2 MB  anaconda
#     eigen-3.3.7                |       haf03e11_1         968 KB  anaconda
#     ffmpeg-4.2.2               |       h97e5cf8_0        43.4 MB  anaconda
#     giflib-5.2.1               |       haf1e3a3_0          73 KB  anaconda
#     gmp-6.2.1                  |       he9d5cce_3         799 KB  anaconda
#     gnutls-3.6.15              |       hed9c0bf_0         1.2 MB  anaconda
#     gst-plugins-base-1.14.0    |       h4180768_2         1.7 MB  anaconda
#     gstreamer-1.14.0           |       h0fc69c2_2         1.2 MB  anaconda
#     idna-3.3                   |     pyhd3eb1b0_0          55 KB  anaconda
#     krb5-1.19.2                |       hcd88c3b_0         1.2 MB  anaconda
#     lame-3.100                 |       h1de35cc_0         496 KB  anaconda
#     libclang-12.0.0            |default_hbc2896b_2        14.7 MB  anaconda
#     libedit-3.1.20210910       |       hca72f7f_0         163 KB  anaconda
#     libidn2-2.3.2              |       h9ed2024_0         102 KB  anaconda
#     libllvm12-12.0.0           |       h9b2ccf5_3        24.2 MB  anaconda
#     libmxnet-1.5.1             |openblas_h49d4b53_0        10.4 MB
#     libopus-1.3.1              |       h1de35cc_0         590 KB  anaconda
#     libpq-12.9                 |       h1c9f633_3         2.8 MB  anaconda
#     libtasn1-4.16.0            |       h9ed2024_0          55 KB  anaconda
#     libunistring-0.9.10        |       h9ed2024_0         623 KB  anaconda
#     libvpx-1.7.0               |       h378b8a2_0         2.3 MB  anaconda
#     libwebp-1.2.2              |       h56c3ce4_0          82 KB  anaconda
#     libxslt-1.1.35             |       h5b33f42_0         566 KB  anaconda
#     mxnet-1.5.1                |       hecd8cb5_0          10 KB
#     nettle-3.7.3               |       h230ac6f_1         423 KB  anaconda
#     nspr-4.33                  |       he9d5cce_0         250 KB  anaconda
#     nss-3.74                   |       h47edf6a_0         2.0 MB  anaconda
#     opencv-4.6.0               |   py37h07fba90_3        26.0 MB
#     openh264-2.1.1             |       h8346a28_0         1.5 MB  anaconda
#     openjpeg-2.4.0             |       h66ea3da_0         473 KB  anaconda
#     ply-3.11                   |           py37_0          80 KB  anaconda
#     py-mxnet-1.5.1             |   py37h60310c3_0         833 KB
#     pyopenssl-22.0.0           |     pyhd3eb1b0_0          49 KB  anaconda
#     pyqt-5.15.7                |   py37he9d5cce_0         4.0 MB
#     pyqt5-sip-12.11.0          |   py37he9d5cce_0          75 KB
#     pysocks-1.7.1              |   py37hecd8cb5_0          30 KB  anaconda
#     qt-5.15.9                  |       hecd8cb5_0          10 KB
#     requests-2.27.1            |     pyhd3eb1b0_0          52 KB  anaconda
#     sip-6.6.2                  |   py37he9d5cce_0         420 KB
#     urllib3-1.26.9             |   py37hecd8cb5_0         177 KB  anaconda
#     x264-1!157.20191217        |       h1de35cc_0         2.5 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:       148.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   _mutex_mxnet       pkgs/main/osx-64::_mutex_mxnet-0.0.50-openblas
#   brotlipy           anaconda/osx-64::brotlipy-0.7.0-py37h9ed2024_1003
#   bzip2              anaconda/osx-64::bzip2-1.0.8-h1de35cc_0
#   charset-normalizer anaconda/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   cryptography       anaconda/osx-64::cryptography-37.0.1-py37hf6deb26_0
#   eigen              anaconda/osx-64::eigen-3.3.7-haf03e11_1
#   ffmpeg             anaconda/osx-64::ffmpeg-4.2.2-h97e5cf8_0
#   giflib             anaconda/osx-64::giflib-5.2.1-haf1e3a3_0
#   gmp                anaconda/osx-64::gmp-6.2.1-he9d5cce_3
#   gnutls             anaconda/osx-64::gnutls-3.6.15-hed9c0bf_0
#   gst-plugins-base   anaconda/osx-64::gst-plugins-base-1.14.0-h4180768_2
#   gstreamer          anaconda/osx-64::gstreamer-1.14.0-h0fc69c2_2
#   idna               anaconda/noarch::idna-3.3-pyhd3eb1b0_0
#   krb5               anaconda/osx-64::krb5-1.19.2-hcd88c3b_0
#   lame               anaconda/osx-64::lame-3.100-h1de35cc_0
#   libclang           anaconda/osx-64::libclang-12.0.0-default_hbc2896b_2
#   libedit            anaconda/osx-64::libedit-3.1.20210910-hca72f7f_0
#   libidn2            anaconda/osx-64::libidn2-2.3.2-h9ed2024_0
#   libllvm12          anaconda/osx-64::libllvm12-12.0.0-h9b2ccf5_3
#   libmxnet           pkgs/main/osx-64::libmxnet-1.5.1-openblas_h49d4b53_0
#   libopus            anaconda/osx-64::libopus-1.3.1-h1de35cc_0
#   libpq              anaconda/osx-64::libpq-12.9-h1c9f633_3
#   libtasn1           anaconda/osx-64::libtasn1-4.16.0-h9ed2024_0
#   libunistring       anaconda/osx-64::libunistring-0.9.10-h9ed2024_0
#   libvpx             anaconda/osx-64::libvpx-1.7.0-h378b8a2_0
#   libwebp            anaconda/osx-64::libwebp-1.2.2-h56c3ce4_0
#   libxslt            anaconda/osx-64::libxslt-1.1.35-h5b33f42_0
#   mxnet              pkgs/main/osx-64::mxnet-1.5.1-hecd8cb5_0
#   nettle             anaconda/osx-64::nettle-3.7.3-h230ac6f_1
#   nspr               anaconda/osx-64::nspr-4.33-he9d5cce_0
#   nss                anaconda/osx-64::nss-3.74-h47edf6a_0
#   opencv             pkgs/main/osx-64::opencv-4.6.0-py37h07fba90_3
#   openh264           anaconda/osx-64::openh264-2.1.1-h8346a28_0
#   openjpeg           anaconda/osx-64::openjpeg-2.4.0-h66ea3da_0
#   ply                anaconda/osx-64::ply-3.11-py37_0
#   py-mxnet           pkgs/main/osx-64::py-mxnet-1.5.1-py37h60310c3_0
#   pyopenssl          anaconda/noarch::pyopenssl-22.0.0-pyhd3eb1b0_0
#   pyqt5-sip          pkgs/main/osx-64::pyqt5-sip-12.11.0-py37he9d5cce_0
#   pysocks            anaconda/osx-64::pysocks-1.7.1-py37hecd8cb5_0
#   qt-main            pkgs/main/osx-64::qt-main-5.15.2-h719ae48_7
#   qt-webengine       pkgs/main/osx-64::qt-webengine-5.15.9-h90a370e_4
#   qtwebkit           pkgs/main/osx-64::qtwebkit-5.212-h24dc246_4
#   requests           anaconda/noarch::requests-2.27.1-pyhd3eb1b0_0
#   urllib3            anaconda/osx-64::urllib3-1.26.9-py37hecd8cb5_0
#   x264               anaconda/osx-64::x264-1!157.20191217-h1de35cc_0
#
# The following packages will be UPDATED:
#
#   libopenblas                             0.3.20-h9a5756b_1 --> 0.3.21-h54e7dc3_0
#   pyqt                  anaconda::pyqt-5.9.2-py37h655552a_0 --> pkgs/main::pyqt-5.15.7-py37he9d5cce_0
#   qt                          anaconda::qt-5.9.7-h468cd18_1 --> pkgs/main::qt-5.15.9-hecd8cb5_0
#   sip                    anaconda::sip-6.5.1-py37he9d5cce_0 --> pkgs/main::sip-6.6.2-py37he9d5cce_0
#
#
# Proceed ([y]/n)?
#
# Downloading and Extracting Packages
# libmxnet-1.5.1       | 10.4 MB   | ##################################### | 100%
# idna-3.3             | 55 KB     | ##################################### | 100%
# gstreamer-1.14.0     | 1.2 MB    | ##################################### | 100%
# gst-plugins-base-1.1 | 1.7 MB    | ##################################### | 100%
# py-mxnet-1.5.1       | 833 KB    | ##################################### | 100%
# lame-3.100           | 496 KB    | ##################################### | 100%
# pyqt5-sip-12.11.0    | 75 KB     | ##################################### | 100%
# bzip2-1.0.8          | 104 KB    | ##################################### | 100%
# libllvm12-12.0.0     | 24.2 MB   | ##################################### | 100%
# libxslt-1.1.35       | 566 KB    | ##################################### | 100%
# urllib3-1.26.9       | 177 KB    | ##################################### | 100%
# opencv-4.6.0         | 26.0 MB   | ##################################### | 100%
# ffmpeg-4.2.2         | 43.4 MB   | ##################################### | 100%
# libwebp-1.2.2        | 82 KB     | ##################################### | 100%
# libedit-3.1.20210910 | 163 KB    | ##################################### | 100%
# cryptography-37.0.1  | 1.2 MB    | ##################################### | 100%
# mxnet-1.5.1          | 10 KB     | ##################################### | 100%
# pyqt-5.15.7          | 4.0 MB    | ##################################### | 100%
# openjpeg-2.4.0       | 473 KB    | ##################################### | 100%
# qt-5.15.9            | 10 KB     | ##################################### | 100%
# libidn2-2.3.2        | 102 KB    | ##################################### | 100%
# openh264-2.1.1       | 1.5 MB    | ##################################### | 100%
# sip-6.6.2            | 420 KB    | ##################################### | 100%
# requests-2.27.1      | 52 KB     | ##################################### | 100%
# charset-normalizer-2 | 33 KB     | ##################################### | 100%
# giflib-5.2.1         | 73 KB     | ##################################### | 100%
# krb5-1.19.2          | 1.2 MB    | ##################################### | 100%
# x264-1!157.20191217  | 2.5 MB    | ##################################### | 100%
# eigen-3.3.7          | 968 KB    | ##################################### | 100%
# brotlipy-0.7.0       | 358 KB    | ##################################### | 100%
# libopus-1.3.1        | 590 KB    | ##################################### | 100%
# libunistring-0.9.10  | 623 KB    | ##################################### | 100%
# libtasn1-4.16.0      | 55 KB     | ##################################### | 100%
# libclang-12.0.0      | 14.7 MB   | ##################################### | 100%
# pyopenssl-22.0.0     | 49 KB     | ##################################### | 100%
# libpq-12.9           | 2.8 MB    | ##################################### | 100%
# ply-3.11             | 80 KB     | ##################################### | 100%
# pysocks-1.7.1        | 30 KB     | ##################################### | 100%
# gmp-6.2.1            | 799 KB    | ##################################### | 100%
# nspr-4.33            | 250 KB    | ##################################### | 100%
# libvpx-1.7.0         | 2.3 MB    | ##################################### | 100%
# nettle-3.7.3         | 423 KB    | ##################################### | 100%
# gnutls-3.6.15        | 1.2 MB    | ##################################### | 100%
# nss-3.74             | 2.0 MB    | ##################################### | 100%
# _mutex_mxnet-0.0.50  | 10 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done

# %%
import mxnet as mx
user = mx.symbol.Variable('user')
item = mx.symbol.Variable('item')
score = mx.symbol.Variable('score')

# Set dummy dimensions
k = 64
max_user = 100
max_item = 50

# user feature lookup
user = mx.symbol.Embedding(data = user, input_dim = max_user, output_dim = k)

# item feature lookup
item = mx.symbol.Embedding(data = item, input_dim = max_item, output_dim = k)

# predict by the inner product, which is elementwise product and then sum
net = user * item
net = mx.symbol.sum_axis(data = net, axis = 1)
net = mx.symbol.Flatten(data = net)

# loss layer
net = mx.symbol.LinearRegressionOutput(data = net, label = score)

# Visualize your network
mx.viz.plot_network(net)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/opt/anaconda3/envs/ai/lib/python3.7/site-packages/mxnet/visualization.py in plot_network(symbol, title, save_format, shape, dtype, node_attrs, hide_weights)
#     272     try:
# --> 273         from graphviz import Digraph
#     274     except:
#
# ModuleNotFoundError: No module named 'graphviz'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /var/folders/gc/jb6dhmdd3r37x6bvx8rw9w980000gn/T/ipykernel_8973/3585450141.py in <module>
#      24
#      25 # Visualize your network
# ---> 26 mx.viz.plot_network(net)
#
# ~/opt/anaconda3/envs/ai/lib/python3.7/site-packages/mxnet/visualization.py in plot_network(symbol, title, save_format, shape, dtype, node_attrs, hide_weights)
#     273         from graphviz import Digraph
#     274     except:
# --> 275         raise ImportError("Draw network requires graphviz library")
#     276     if not isinstance(symbol, Symbol):
#     277         raise TypeError("symbol must be a Symbol")
#
# ImportError: Draw network requires graphviz library
